# %% [markdown]
# # Evaluation Project - 10
#
# Zomato Restaurant Project
#
# Problem Statement:
#     Zomato Data Analysis is one of the most useful analysis for foodies
#     who want to taste the best cuisines of every part of the world which
#     lies in their budget. This analysis is also for those who want to find
#     the value for money restaurants in various parts of the country for the
#     cuisines Additionally, this analysis caters the needs of people who are
#     striving to get the best cuisine ofthe country and which locality of that country serves that cuisines with maximum number of
#     restaurants.

# %% [markdown]
# #Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#  Country code
#  Country name
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies ��
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people

# %% [markdown]
# # Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range
#
# Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine
#        two datasets

# %%
! pip install pandas-profiling[notebook]
# Out:
# Requirement already satisfied: pandas-profiling[notebook] in c:\users\satya\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (2.26.0)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.1.12)
# Requirement already satisfied: multimethod<1.9,>=1.4 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.8)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.12.2)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.23.4)
# Requirement already satisfied: matplotlib<3.6,>=3.2 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (3.4.3)
# Requirement already satisfied: missingno<0.6,>=0.4.2 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.5.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (4.62.3)
# Requirement already satisfied: seaborn<0.12,>=0.10.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.11.2)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.9.2)
# Requirement already satisfied: pandas!=1.4.0,<1.5,>1.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.3.4)
# Requirement already satisfied: pydantic<1.10,>=1.8.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.9.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (3.0.3)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.13.2)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (1.1.0)
# Requirement already satisfied: jupyter-core>=4.6.3 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (4.8.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (6.1.12)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\satya\anaconda3\lib\site-packages (from pandas-profiling[notebook]) (7.6.5)
# Requirement already satisfied: networkx>=2.4 in c:\users\satya\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\satya\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (21.2.0)
# Requirement already satisfied: imagehash in c:\users\satya\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\satya\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (8.4.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (7.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.0.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\satya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\satya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.1)
# Requirement already satisfied: pygments in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (58.0.4)
# Requirement already satisfied: decorator in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.0)
# Requirement already satisfied: backcall in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.0)
# Requirement already satisfied: colorama in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\satya\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling[notebook]) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (228)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling[notebook]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling[notebook]) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling[notebook]) (3.0.4)
# Requirement already satisfied: six in c:\users\satya\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<3.6,>=3.2->pandas-profiling[notebook]) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\satya\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\satya\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\satya\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.5,>1.1->pandas-profiling[notebook]) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\satya\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\satya\anaconda3\lib\site-packages (from pydantic<1.10,>=1.8.1->pandas-profiling[notebook]) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\satya\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\satya\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling[notebook]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\satya\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling[notebook]) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\satya\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling[notebook]) (1.26.7)
# Requirement already satisfied: packaging>=21.3 in c:\users\satya\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling[notebook]) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\satya\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling[notebook]) (0.5.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\satya\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.4.5)
# Requirement already satisfied: argon2-cffi in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.11.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\satya\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\satya\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.20)
# Requirement already satisfied: PyWavelets in c:\users\satya\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: testpath in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.3)
# Requirement already satisfied: bleach in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.3)
# Requirement already satisfied: nest-asyncio in c:\users\satya\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\satya\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.10)
# Requirement already satisfied: webencodings in c:\users\satya\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.1)

# %%
 conda install -c conda-forge pandas-profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\satya\anaconda3
#
#   added / updated specs:
#     - pandas-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.9.0               |   py39hcbf5309_1         968 KB  conda-forge
#     pandas-profiling-1.4.1     |                0          40 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1013 KB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-profiling   conda-forge/win-64::pandas-profiling-1.4.1-0
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.14.0-py39haa95532_0 --> conda-forge::conda-22.9.0-py39hcbf5309_1
#
#
#
# Downloading and Extracting Packages
#
# conda-22.9.0         | 968 KB    |            |   0%
# conda-22.9.0         | 968 KB    | 1          |   2%
# conda-22.9.0         | 968 KB    | ########5  |  86%
# conda-22.9.0         | 968 KB    | ########## | 100%
#
# pandas-profiling-1.4 | 40 KB     |            |   0%
# pandas-profiling-1.4 | 40 KB     | ####       |  40%
# pandas-profiling-1.4 | 40 KB     | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
 conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install sweetviz &> /dev/null                             # Package for some sweet visualizations
! pip install -U dataprep &> /dev/null                          # Package for instant data preparation
! pip install --upgrade plotly &> /dev/null                     # Updating plotly to the latest version
! pip install jupyter-dash &> /dev/null
# Out:
# Requirement already satisfied: sweetviz in c:\users\satya\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (3.0.3)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (3.4.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (5.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (4.62.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (1.3.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\satya\anaconda3\lib\site-packages (from sweetviz) (1.9.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\satya\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: six in c:\users\satya\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\satya\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Requirement already satisfied: colorama in c:\users\satya\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.4)
# The system cannot find the path specified.
# The system cannot find the path specified.
# Requirement already satisfied: dataprep in c:\users\satya\anaconda3\lib\site-packages (0.4.5)
# Requirement already satisfied: flask_cors<4.0.0,>=3.0.10 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (3.0.10)
# Requirement already satisfied: pydot<2.0.0,>=1.4.2 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.4.2)
# Requirement already satisfied: jsonpath-ng<2.0,>=1.5 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.5.3)
# Requirement already satisfied: scipy<2.0,>=1.8 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.9.2)
# Requirement already satisfied: regex<2022.0.0,>=2021.8.3 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (2021.8.3)
# Requirement already satisfied: sqlalchemy==1.3.24 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.3.24)
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (2022.9.2)
# Requirement already satisfied: python-stdnum<2.0,>=1.16 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.17)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (7.6.5)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.3.4)
# Requirement already satisfied: varname<0.9.0,>=0.8.1 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (0.8.3)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (3.7)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.8.2.2)
# Requirement already satisfied: python-crfsuite==0.9.8 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (0.9.8)
# Requirement already satisfied: jinja2<3.1,>=3.0 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (3.0.3)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (3.8.3)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (2.4.1)
# Requirement already satisfied: metaphone<0.7,>=0.6 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (0.6)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.1.2 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (2.11.1)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.9.2)
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (1.23.4)
# Requirement already satisfied: flask<3,>=2 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (2.2.2)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\satya\anaconda3\lib\site-packages (from dataprep) (4.62.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (21.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\satya\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\satya\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (8.4.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\satya\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\satya\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\satya\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (3.10.0.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\satya\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\satya\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.11.1)
# Requirement already satisfied: partd>=0.3.10 in c:\users\satya\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\satya\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\satya\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2021.10.1)
# Requirement already satisfied: click>=8.0 in c:\users\satya\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (8.0.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\satya\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (4.8.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\satya\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.2.2)
# Requirement already satisfied: colorama in c:\users\satya\anaconda3\lib\site-packages (from click>=8.0->flask<3,>=2->dataprep) (0.4.4)
# Requirement already satisfied: Six in c:\users\satya\anaconda3\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\satya\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<3,>=2->dataprep) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.4.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.29.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\satya\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\satya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.12)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\satya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.4.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.20)
# Requirement already satisfied: pygments in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.10.0)
# Requirement already satisfied: backcall in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: decorator in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\satya\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (58.0.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\satya\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Requirement already satisfied: ply in c:\users\satya\anaconda3\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\satya\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (228)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\satya\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\satya\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: joblib in c:\users\satya\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\satya\anaconda3\lib\site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\satya\anaconda3\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.3)
# Requirement already satisfied: locket in c:\users\satya\anaconda3\lib\site-packages\locket-0.2.1-py3.9.egg (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\satya\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in c:\users\satya\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.3)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\satya\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\satya\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.5)
# Requirement already satisfied: nbconvert in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\satya\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\satya\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.7)
# Requirement already satisfied: matplotlib in c:\users\satya\anaconda3\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.4.3)
# Requirement already satisfied: idna>=2.0 in c:\users\satya\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.2)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\satya\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\satya\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.20)
# Requirement already satisfied: cycler>=0.10 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\satya\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.3)
# Requirement already satisfied: defusedxml in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: bleach in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.3)
# Requirement already satisfied: testpath in c:\users\satya\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: async-generator in c:\users\satya\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\satya\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\satya\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: plotly in c:\users\satya\anaconda3\lib\site-packages (5.10.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\satya\anaconda3\lib\site-packages (from plotly) (8.1.0)
# The system cannot find the path specified.
# The syntax of the command is incorrect.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

import warnings
warnings.filterwarnings('ignore')

# %%
zomatodt = pd.read_csv("D:\Data Trained - Excel links\zomato.csv", encoding = "ISO-8859-1")

# %%
# Viewing shape of the data
zomatodt.shape
# Out:
# (9551, 21)

# %%
# Viewing the top 3 rows of the dataset
zomatodt.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
#
# [3 rows x 21 columns]

# %% [markdown]
# From the above data, we can observe the following:
#
# Restaurant Data:
# Location Data:
# Food Data:
# Costing Data:
# Order Details:
# Restaurant Rating Details:
#
# we proceed to understand the data, summary statistics, data types and missing values better.

# %%
# Reading country code 
countrydt = pd.read_excel("D:\Data Trained - Excel links\Country-Code.xlsx")

# %%
# Viewing the shape of the dataset
countrydt.shape
# Out:
# (15, 2)

# %%
# Viewing the top 5 results of the country Dataframe
countrydt.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# Viewing the Zomato Dataset
zomatodt.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
#
# [3 rows x 21 columns]

# %% [markdown]
# Now Merging the Zomato and Country Datasets

# %%
# Merging the zomato dataset at Restaurant Id level and Country data at country code level
zomatoCountrydt = pd.merge(zomatodt, countrydt, on = 'Country Code')

# %%
# Viewing the head of the 
zomatoCountrydt.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes      Country
# 0              4.8    Dark Green    Excellent   314  Phillipines
# 1              4.5    Dark Green    Excellent   591  Phillipines
# 2              4.4         Green    Very Good   270  Phillipines
#
# [3 rows x 22 columns]

# %%
# Summary of the dataset now
print(zomatoCountrydt.info(verbose=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
#  21  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB
# None

# %% [markdown]
# MISSING VALUE ANALYSIS

# %%
# Printing all the columns with atleast one null value
zomatoCountrydt.columns[zomatoCountrydt.isna().any()].tolist()
# Out:
# ['Cuisines']

# %% [markdown]
# From above:
# #The dataset has 9551 rows and 22 columns
# #There are 3 columns with float, 5 columns with int, 14 columns that are categorical
# #There is one column 'Cuisines' that has missing values

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Pandas Profiling

# %%
import pandas_profiling                             # Automatic EDA
import sweetviz as sv                               # Importing sweetviz for some sweet visualizations
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8280/2072416623.py in <module>
# ----> 1 import pandas_profiling                             # Automatic EDA
#       2 import sweetviz as sv                               # Importing sweetviz for some sweet visualizations
#       3 import seaborn as sns
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#      10 import pandas_profiling.templates as templates
#      11 from .describe import describe
# ---> 12 from .report import to_html
#      13
#      14 NO_OUTPUTFILE = "pandas_profiling.no_outputfile"
#
# ImportError: cannot import name 'to_html' from 'pandas_profiling.report' (C:\Users\satya\anaconda3\lib\site-packages\pandas_profiling\report\__init__.py)

# %%
# Making a copy of the dataset as df
dt = zomatoCountrydt.copy(deep = True)

# %%
# Generating the profile report and feeding it into a variable
# zomatoPandasProfile = ProfileReport(df, title = 'Zomato Data: Pandas Profiling Report', html = {'style':{'full_width':True}})

# %%
# Showcasing the Pandas Profiling Report for the Zomato Dataset
# zomatoPandasProfile

# %%
# We shall use the SweetViz analyze() function to generate a shareable .html file to analyze the dataset
analyze_report = sv.analyze(dt)
# analyze_report.show_html('zomatoSweetViz.html', open_browser=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8280/1019934664.py in <module>
#       1 # We shall use the SweetViz analyze() function to generate a shareable .html file to analyze the dataset
# ----> 2 analyze_report = sv.analyze(dt)
#       3 # analyze_report.show_html('zomatoSweetViz.html', open_browser=False)
#
# NameError: name 'sv' is not defined

# %%
# Displaying the html file in the Google Colab notebook
# IPython.display.HTML('zomatoSweetViz.html')

# %% [markdown]
# Data Preparation

# %%
# Plotting the features of the dataframe
# plot(dt)

# %%
------------------------ I tried many times to update my kernel and also tried to instal my notebook,
                      But no use, some libraries are not installing - withour that i cant move ahead in the program.
                      I tried my level best - and wil try again

# %%
REMARKS - I tried a lot to manage the things ,
but i am unable to install some python libraries and import some sweetviz libraries. and also others.
# if i postively get all my errors done, further i will surely resubmit the assignment again.
Kinldy excuse for not geeting the results.
